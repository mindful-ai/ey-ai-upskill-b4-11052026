# %% [markdown]
# ### Huggingface

# %% [markdown]
# ##### Reading the API Key from the vault

# %%
path = r"E:\Lenovo Ideapad 330\company-material\ai-upskill-3\key-vault\huggingface\ey-b2-ai-upskill.txt"

# %%
f = open(path, 'r')
api_key = f.read()
f.close()

# %%
api_key[:5]
# Out:
# 'hf_xN'

# %%
#!pip install openai

# %%
import os
from openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 from openai import OpenAI
#
# ModuleNotFoundError: No module named 'openai'

# %% [markdown]
# ###### Alternatively, we can use python's requests module for sending the HTTP request to the HF server

# %%
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=api_key
)
client

# %%
response = client.chat.completions.create(
    model="Qwen/Qwen2.5-72B-Instruct:fastest",
    messages=[
        {"role": "system", "content":"You are a helpful and brief AI."},
        {"role": "user", "content": "Tell me 5 facts about Voyager 1"}
    ],
    max_tokens=500,
)

# %%
print(response.choices[0].message.content)
# Out:
# 1. **Launch Date**: Voyager 1 was launched on September 5, 1977.
# 2. **Farthest Human-Made Object**: It is the most distant human-made object from Earth, currently over 15 billion miles away.
# 3. **Interstellar Space**: In 2012, Voyager 1 became the first spacecraft to enter interstellar space.
# 4. **Golden Record**: It carries a Golden Record containing sounds and images selected to portray the diversity of life and culture on Earth.
# 5. **Power Source**: Voyager 1 is powered by three radioisotope thermoelectric generators (RTGs) that convert heat from decaying plutonium into electricity.

# %% [markdown]
# ### GROQ - https://groq.com/

# %%
# !pip install groq
# Out:
# Requirement already satisfied: groq in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from groq) (2.13.3)
# Requirement already satisfied: sniffio in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from httpx<1,>=0.23.0->groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\lenovo ideapad 330\company-material\ai-upskill-2\ai\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### Using OpenAI Client

# %%
f = open(r"E:\Lenovo Ideapad 330\company-material\ai-upskill\key-vault\groq\groq-api-key.txt")
groq_api_key = f.read()
f.close()

# %%
from groq import Groq

# %%
client = Groq(api_key=groq_api_key)

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content":"You are a helpful and brief AI."},
        {"role": "user", "content": "Tell me 5 facts about Voyager 1"}
    ],
    max_tokens=500,
)

# %%
print(response.choices[0].message.content)
# Out:
# Here are five key facts about Voyager 1:
#
# 1. **Launch Date**: Voyager 1 was launched on September 5, 1977, from Cape Canaveral, Florida, USA.
# 2. **Interstellar Space**: It is the most distant human-made object, having entered interstellar space in August 2012. Voyager 1 is about 14.5 billion miles (23.3 billion km) from Earth.
# 3. **Speed**: The spacecraft moves at a speed of about 38,000 miles per hour (61,155 km/h), making it one of the fastest objects ever built.
# 4. **Golden Records**: Each Voyager spacecraft carries a gold-plated copper record containing sounds and images of Earth, known as the Golden Records. These records are intended to serve as a message to any extraterrestrial life form that may encounter the spacecraft.
# 5. **Mission Objectives**: Voyager 1 was initially designed to study the outer Solar System and beyond, with primary objectives including exploring Jupiter and Saturn, as well as their moons and rings.
