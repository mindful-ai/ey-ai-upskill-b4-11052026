# %% [markdown]
# # Seaborn

# %% [markdown]
# ### Installation

# %%
# %pip install seaborn

# %% [markdown]
# ### Import Seaborn

# %%
import seaborn as sns
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"tips.csv")
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Categorical Plots

# %% [markdown]
# ### Bar Plot

# %%
sns.barplot(x=df["gender"], y=df["total_bill"], data=df)
# Out:
# <Axes: xlabel='gender', ylabel='total_bill'>

# %%
sns.barplot(x=df["gender"], y=df["total_bill"], data=df, estimator=np.std)
# Out:
# <Axes: xlabel='gender', ylabel='total_bill'>

# %% [markdown]
# ### Count Plot

# %%
sns.countplot(x=df["gender"], data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# ### Box Plots

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x=df['gender'],y=df['total_bill'],data=df)
# Out:
# <Axes: xlabel='gender', ylabel='total_bill'>

# %%
sns.boxplot(x=df['day'],y=df['total_bill'],data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df, orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x='day',y='total_bill',data=df, hue="gender", palette="coolwarm")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Violin Plots

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot(x="day", y="total_bill", data=df, palette="Set1")
# Out:
# C:\Users\mindf\AppData\Local\Temp\ipykernel_35176\2993430909.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day", y="total_bill", data=df, palette="Set1")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=df, palette="Set1", hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=df, palette="Set1", hue="gender", split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Strip Plot

# %%
sns.stripplot(x='day', y='total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=df, hue='gender', palette="viridis")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Swarm Plot

# %%
sns.swarmplot(x="day", y ="total_bill", data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y ="total_bill", data=df, hue='gender', palette="Set1")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ### distplot

# %%
sns.histplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df["total_bill"], kde=False)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### jointplot

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='kde')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='resid')

# %% [markdown]
# ### pairplot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="gender", palette='coolwarm')

# %% [markdown]
# ### Heat Maps

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.heatmap(df[['total_bill', 'tip']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df[['total_bill', 'tip']].corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Regression PLot

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='gender')

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='gender', markers=['o', 'v'], palette='coolwarm')
